# %%
# !wget --no-check-certificate \
  https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pemula_academy/rockpaperscissors.zip \
  -O /tmp/rockpaperscissors.zip
# Out:
# --2020-11-02 21:29:21--  https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pemula_academy/rockpaperscissors.zip
# Resolving dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)... 52.239.197.36
# Connecting to dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)|52.239.197.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322873683 (308M) [application/zip]
# Saving to: ‘/tmp/rockpaperscissors.zip’
#
# /tmp/rockpapersciss 100%[===================>] 307.92M  9.48MB/s    in 44s
#
# 2020-11-02 21:30:06 (7.04 MB/s) - ‘/tmp/rockpaperscissors.zip’ saved [322873683/322873683]

# %%
# mengimport dan mengekstraksi
import os
import zipfile

local_zip = '/tmp/rockpaperscissors.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
# melakukan pemeriksaan direktori file
os.listdir('/tmp/rockpaperscissors/')
# Out:
# ['rps-cv-images', 'rock', 'paper', 'README_rpc-cv-images.txt', 'scissors']

# %%
# mengubah direktori ke path dibawah
os.chdir('/tmp/rockpaperscissors/rps-cv-images')
os.listdir()
# Out:
# ['rock', 'paper', 'README_rpc-cv-images.txt', 'scissors']

# %%
# menghapus file yang tidak dibutuhkan
os.remove('README_rpc-cv-images.txt')
os.listdir()
# Out:
# ['rock', 'paper', 'scissors']

# %%
train_dir = os.path.join('/tmp/rockpaperscissors/rps-cv-images')
train_dir
# Out:
# '/tmp/rockpaperscissors/rps-cv-images'

# %%
import tensorflow as tf
# from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# melakukan augmentasi pada data
train_datagen = ImageDataGenerator(
                  validation_split=0.4,
                  rescale=1./255,
                  rotation_range=20,
                  shear_range=0.2,
                  width_shift_range=0.1,
                  height_shift_range=0.1,
                  horizontal_flip = True,
                  vertical_flip = True,
                  fill_mode = 'wrap')

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    subset='training')
validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 1314 images belonging to 3 classes.
# Found 874 images belonging to 3 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(128, 128, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.2),  
    tf.keras.layers.Flatten(), 
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')  
])

# %%
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history = model.fit(train_generator,
                    validation_data=validation_generator,
                    epochs=20,
                    verbose=2)
# Out:
# Epoch 1/20
# 42/42 - 52s - loss: 0.1986 - accuracy: 0.9277 - val_loss: 0.3542 - val_accuracy: 0.8616
# Epoch 2/20
# 42/42 - 52s - loss: 0.1636 - accuracy: 0.9444 - val_loss: 0.1839 - val_accuracy: 0.9348
# Epoch 3/20
# 42/42 - 52s - loss: 0.1704 - accuracy: 0.9437 - val_loss: 0.3411 - val_accuracy: 0.8764
# Epoch 4/20
# 42/42 - 52s - loss: 0.1976 - accuracy: 0.9216 - val_loss: 0.1691 - val_accuracy: 0.9508
# Epoch 5/20
# 42/42 - 55s - loss: 0.1497 - accuracy: 0.9543 - val_loss: 0.2016 - val_accuracy: 0.9336
# Epoch 6/20
# 42/42 - 52s - loss: 0.3142 - accuracy: 0.8988 - val_loss: 0.2785 - val_accuracy: 0.9256
# Epoch 7/20
# 42/42 - 52s - loss: 0.1950 - accuracy: 0.9368 - val_loss: 0.1561 - val_accuracy: 0.9462
# Epoch 8/20
# 42/42 - 52s - loss: 0.1271 - accuracy: 0.9627 - val_loss: 0.1354 - val_accuracy: 0.9634
# Epoch 9/20
# 42/42 - 52s - loss: 0.1309 - accuracy: 0.9498 - val_loss: 0.1680 - val_accuracy: 0.9565
# Epoch 10/20
# 42/42 - 51s - loss: 0.1368 - accuracy: 0.9581 - val_loss: 0.1541 - val_accuracy: 0.9508
# Epoch 11/20
# 42/42 - 52s - loss: 0.1445 - accuracy: 0.9559 - val_loss: 0.1752 - val_accuracy: 0.9508
# Epoch 12/20
# 42/42 - 53s - loss: 0.1356 - accuracy: 0.9581 - val_loss: 0.2182 - val_accuracy: 0.9325
# Epoch 13/20
# 42/42 - 53s - loss: 0.1055 - accuracy: 0.9658 - val_loss: 0.1628 - val_accuracy: 0.9451
# Epoch 14/20
# 42/42 - 53s - loss: 0.0971 - accuracy: 0.9604 - val_loss: 0.1187 - val_accuracy: 0.9691
# Epoch 15/20
# 42/42 - 53s - loss: 0.0959 - accuracy: 0.9703 - val_loss: 0.0996 - val_accuracy: 0.9725
# Epoch 16/20
# 42/42 - 52s - loss: 0.1120 - accuracy: 0.9642 - val_loss: 0.1045 - val_accuracy: 0.9737
# Epoch 17/20
# 42/42 - 55s - loss: 0.1032 - accuracy: 0.9612 - val_loss: 0.1133 - val_accuracy: 0.9645
# Epoch 18/20
# 42/42 - 52s - loss: 0.1130 - accuracy: 0.9688 - val_loss: 0.0804 - val_accuracy: 0.9771
# Epoch 19/20
# 42/42 - 52s - loss: 0.0895 - accuracy: 0.9726 - val_loss: 0.1804 - val_accuracy: 0.9291
# Epoch 20/20
# 42/42 - 52s - loss: 0.1004 - accuracy: 0.9680 - val_loss: 0.0894 - val_accuracy: 0.9725

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

# %matplotlib inline

uploaded = files.upload()

for fn in uploaded.keys():

  path = fn 
  img = image.load_img(path, target_size =(128,128))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=32)
  print(classes)

  print('Gambar yang terdeteksi: ', end='')
  if classes[0,0] == 1:
    print('Paper')
  elif classes[0,1] == 1:
    print('Rock')
  else:
    print('Scissors')
# Out:
#      <input type="file" id="files-1b320f75-c842-41fe-a8b0-edd10bf412e6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b320f75-c842-41fe-a8b0-edd10bf412e6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving btu.jpg to btu (1).jpg
# [[1. 0. 0.]]
# Gambar yang terdeteksi: Paper
